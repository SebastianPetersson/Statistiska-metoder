# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
rng = np.random.default_rng(37)

integers = rng.integers(100, size=100)
X
# Out:
# array([15, 70, 63, 66, 26,  6, 91, 70, 28, 31, 80, 45, 94, 98, 21,  6,  1,
#        18, 56, 10, 85, 84, 70, 69, 86, 24, 46, 12, 69, 70, 82, 19, 58, 28,
#        30, 70, 54,  6, 20, 30, 25, 50, 15, 63, 25, 39, 28, 99, 61, 76, 41,
#         0, 75, 33, 38,  2, 30, 84, 23, 11, 65, 36, 68, 79, 83, 38, 46,  2,
#        16, 26, 81, 33, 84, 56, 45, 76, 89, 54, 43,  1,  8, 84, 73, 41, 93,
#        75, 31, 23, 96,  3, 30, 35, 88, 80, 15, 96, 42, 55, 63, 78])

# %%
fig, axes = plt.subplots(2, 2, figsize=(12,8))


sns.histplot(integers, ax=axes[0,0], cumulative=True, stat="frequency", element="step") #cumulative=True skapar en ogive, istället för att datan delas in i olika bins som vanligt.

axes[0,0].set_title("100 random integers")
plt.show()
